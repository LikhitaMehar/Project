# %% [markdown]
# <a href="https://colab.research.google.com/github/LikhitaMehar/Project/blob/main/HR_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ab=pd.read_csv("/content/drive/MyDrive/HR Analysis project/HR_Analytics.csv")
ab
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18    18-25       Yes      Travel_Rarely        230
# 1      RM302   18    18-25        No      Travel_Rarely        812
# 2      RM458   18    18-25       Yes  Travel_Frequently       1306
# 3      RM728   18    18-25        No         Non-Travel        287
# 4      RM829   18    18-25       Yes         Non-Travel        247
# ...      ...  ...      ...       ...                ...        ...
# 1475   RM412   60      55+        No      Travel_Rarely        422
# 1476   RM428   60      55+        No  Travel_Frequently       1499
# 1477   RM537   60      55+        No      Travel_Rarely       1179
# 1478   RM880   60      55+        No      Travel_Rarely        696
# 1479  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# 0     Research & Development                 3          3  Life Sciences  ...
# ...

# %%
ab.nunique()
# Out:
# EmpID                       1470
# Age                           43
# AgeGroup                       5
# Attrition                      2
# BusinessTravel                 4
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# SalarySlab                     4
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# ...

# %%
ab.columns
# Out:
# Index(['EmpID', 'Age', 'AgeGroup', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'SalarySlab',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.bar(ab["YearsAtCompany"],ab["MonthlyIncome"])
plt.show()

# %%
plt.hist(ab['YearsAtCompany'], bins=10, color='skyblue', edgecolor='black')

plt.xlabel('Years Worked')
plt.ylabel('Number of Employees')
plt.title('Number of Years Employees Have Worked in the Company')
plt.show()

# %%
import matplotlib.pyplot as plt
Satisfaction=ab["JobSatisfaction"].value_counts()
values = [4,3,2,1]
labels=["4-Excellent","3-Good","2-Satisfactory","1-Below Satisfactory"]
plt.pie(Satisfaction,labels=values,startangle=90,autopct='%.2f')
plt.title("Job Satisfaction of the overall employees working in the company")
plt.legend(labels)
plt.xlabel("Job Satisfaction")
plt.ylabel("Satisfaction Percentage")
plt.show()

# %%
ab[(ab["TrainingTimesLastYear"]>3) & (ab["PercentSalaryHike"]==25)].count()
# Out:
# EmpID                       5
# Age                         5
# AgeGroup                    5
# Attrition                   5
# BusinessTravel              5
# DailyRate                   5
# Department                  5
# DistanceFromHome            5
# Education                   5
# EducationField              5
# EmployeeCount               5
# EmployeeNumber              5
# EnvironmentSatisfaction     5
# Gender                      5
# HourlyRate                  5
# JobInvolvement              5
# JobLevel                    5
# JobRole                     5
# JobSatisfaction             5
# MaritalStatus               5
# MonthlyIncome               5
# SalarySlab                  5
# MonthlyRate                 5
# NumCompaniesWorked          5
# Over18                      5
# OverTime                    5
# PercentSalaryHike           5
# PerformanceRating           5
# RelationshipSatisfaction    5
# StandardHours               5
# StockOptionLevel            5
# ...

# %%
ab[ab["PercentSalaryHike"]==25].count()
# Out:
# EmpID                       18
# Age                         18
# AgeGroup                    18
# Attrition                   18
# BusinessTravel              18
# DailyRate                   18
# Department                  18
# DistanceFromHome            18
# Education                   18
# EducationField              18
# EmployeeCount               18
# EmployeeNumber              18
# EnvironmentSatisfaction     18
# Gender                      18
# HourlyRate                  18
# JobInvolvement              18
# JobLevel                    18
# JobRole                     18
# JobSatisfaction             18
# MaritalStatus               18
# MonthlyIncome               18
# SalarySlab                  18
# MonthlyRate                 18
# NumCompaniesWorked          18
# Over18                      18
# OverTime                    18
# PercentSalaryHike           18
# PerformanceRating           18
# RelationshipSatisfaction    18
# StandardHours               18
# ...

# %%
import pandas as pd
cd=pd.read_csv("/content/drive/MyDrive/HR Analysis project/HR_Analytics.csv")
cd
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18    18-25       Yes      Travel_Rarely        230
# 1      RM302   18    18-25        No      Travel_Rarely        812
# 2      RM458   18    18-25       Yes  Travel_Frequently       1306
# 3      RM728   18    18-25        No         Non-Travel        287
# 4      RM829   18    18-25       Yes         Non-Travel        247
# ...      ...  ...      ...       ...                ...        ...
# 1475   RM412   60      55+        No      Travel_Rarely        422
# 1476   RM428   60      55+        No  Travel_Frequently       1499
# 1477   RM537   60      55+        No      Travel_Rarely       1179
# 1478   RM880   60      55+        No      Travel_Rarely        696
# 1479  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# 0     Research & Development                 3          3  Life Sciences  ...
# ...

# %%
cd["MonthlyIncome"].mean()
# Out:
# 6504.985810810811

# %%
cd["Department"].unique()
# Out:
# array(['Research & Development', 'Sales', 'Human Resources'], dtype=object)

# %%
data=cd[(cd["Department"] == "Human Resources") & (cd["JobRole"]=="Manager")]
final = data["MonthlyIncome"].mean()
print(final)
# Out:
# 18088.636363636364

# %%
data1=ab[(ab["Department"] == "Human Resources") & (ab["JobRole"]=="Manager")]
final1 = data1["MonthlyIncome"].mean()
data2=ab[(ab["Department"] == "Research & Development") & (ab["JobRole"]=="Manager")]
final2 = data2["MonthlyIncome"].mean()
data3=ab[(ab["Department"] == "Research & Development") & (ab["JobRole"]=="Laboratory Technician")]
final3 = data3["MonthlyIncome"].mean()
data4=ab[(ab["Department"] == "Human Resources") & (ab["JobRole"]=="Human Resources")]
final4 = data4["MonthlyIncome"].mean()
data5=ab[(ab["Department"] == "Sales") & (ab["JobRole"]=="Manager")]
final5 = data5["MonthlyIncome"].mean()
data6=ab[(ab["Department"] == "Sales") & (ab["JobRole"]=="Sales Executive")]
final6 = data6["MonthlyIncome"].mean()
xaxis=["HR-M","R&D-M","R&D-LT","HR-HR","Sales-M","Sales-SE"]
final=[final1,final2,final3,final4,final5,final6]
plt.bar(xaxis,final)
plt.title("Average Salary Of Different Department and Respective Job Roles")
plt.xlabel("Department and Postion")
plt.ylabel("Average Salary")
plt.show()

# %%
import matplotlib.pyplot as plt
data1 = ab[(ab["Department"] == "Human Resources") & (ab["JobRole"] == "Manager")]
final1 = data1["MonthlyIncome"].mean()
data2 = ab[(ab["Department"] == "Research & Development") & (ab["JobRole"] == "Manager")]
final2 = data2["MonthlyIncome"].mean()
data3 = ab[(ab["Department"] == "Research & Development") & (ab["JobRole"] == "Laboratory Technician")]
final3 = data3["MonthlyIncome"].mean()
data4 = ab[(ab["Department"] == "Human Resources") & (ab["JobRole"] == "Human Resources")]
final4 = data4["MonthlyIncome"].mean()
data5 = ab[(ab["Department"] == "Sales") & (ab["JobRole"] == "Manager")]
final5 = data5["MonthlyIncome"].mean()
data6 = ab[(ab["Department"] == "Sales") & (ab["JobRole"] == "Sales Executive")]
final6 = data6["MonthlyIncome"].mean()
xaxis = ["HR-M", "R&D-M", "R&D-LT", "HR-HR", "Sales-M", "Sales-SE"]
final = [final1, final2, final3, final4, final5, final6]
plt.bar(xaxis, final,color="Grey")
for i, salary in enumerate(final):
    plt.text(i, salary + 100, str(int(salary)), ha='center', va='bottom')
plt.title("Average Salary Of Different Departments and Respective Job Roles")
plt.xlabel("Department and Position")
plt.ylabel("Average Salary")
plt.show()

# %%
import pandas as pd
cd=pd.read_csv("/content/drive/MyDrive/HR Analysis project/HR_Analytics.csv")
data=cd[(cd["Department"] == "Research & Development") & (cd["JobRole"]=="Manager")]
final = data["Gender"].value_counts()
print(final)
# Out:
# Male      30
# Female    24
# Name: Gender, dtype: int64

# %%
data1=ab[(ab["Department"] == "Research & Development") & (ab["JobRole"]=="Manager")]
final1 = data1["Gender"].count()
data2=ab[(ab["Department"] == "Research & Development") & (ab["JobRole"]=="Laboratory Technician")]
final2 = data2["Gender"].count()
data3=ab[(ab["Department"] == "Human Resources") & (ab["JobRole"]=="Manager")]
final3 = data3["Gender"].count()
data4=ab[(ab["Department"] == "Human Resources") & (ab["JobRole"]=="Human Resources")]
final4 = data4["Gender"].count()
data5=ab[(ab["Department"] == "Sales") & (ab["JobRole"]=="Manager")]
final5 = data5["Gender"].count()
data6=ab[(ab["Department"] == "Sales") & (ab["JobRole"]=="Sales Executive")]
final6= data6["Gender"].count()
final=[final1,final2,final3,final4,final5,final6]
xaxis=["R&D-M","R&D-LT","HR-M","HR-HR","Sales-M","Sales-SE"]
plt.bar(xaxis,final)
plt.title("Gender count in each department")
plt.xlabel("Department and Position")
plt.ylabel("Gender count")
plt.show()

# %%
import matplotlib.pyplot as plt
data1 = ab[(ab["Department"] == "Research & Development") & (ab["JobRole"] == "Manager")]
final1 = data1["Gender"].count()
data2 = ab[(ab["Department"] == "Research & Development") & (ab["JobRole"] == "Laboratory Technician")]
final2 = data2["Gender"].count()
data3 = ab[(ab["Department"] == "Human Resources") & (ab["JobRole"] == "Manager")]
final3 = data3["Gender"].count()
data4 = ab[(ab["Department"] == "Human Resources") & (ab["JobRole"] == "Human Resources")]
final4 = data4["Gender"].count()
data5 = ab[(ab["Department"] == "Sales") & (ab["JobRole"] == "Manager")]
final5 = data5["Gender"].count()
data6 = ab[(ab["Department"] == "Sales") & (ab["JobRole"] == "Sales Executive")]
final6 = data6["Gender"].count()

final = [final1, final2, final3, final4, final5, final6]
xaxis = ["R&D-M", "R&D-LT", "HR-M", "HR-HR", "Sales-M", "Sales-SE"]

plt.bar(xaxis, final,color="yellow")

# Add annotations to each bar
for i, count in enumerate(final):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom')

plt.title("Employee count in each department")
plt.xlabel("Department and Position")
plt.ylabel("Employee count")

plt.show()

# %%
department_name = 'Research & Development'
department_df = ab[ab['Department'] == department_name]
gender_counts = department_df['Gender'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'pink'])
plt.title(f'Gender Distribution in {department_name}')
plt.show()

# %%
cd["JobRole"].unique()
# Out:
# array(['Laboratory Technician', 'Sales Representative',
#        'Research Scientist', 'Human Resources', 'Manufacturing Director',
#        'Sales Executive', 'Healthcare Representative',
#        'Research Director', 'Manager'], dtype=object)

# %%
data=cd[(cd["Department"] == "Research & Development") & (cd["JobRole"]=="Manager")]
final = data["JobSatisfaction"].value_counts()
print(final)
# Out:
# 4    17
# 3    16
# 1    15
# 2     6
# Name: JobSatisfaction, dtype: int64

# %%
data=cd[cd["Department"] == "Human Resources"]
final = data["JobSatisfaction"].value_counts()
print(final)
# Out:
# 2    20
# 4    17
# 3    15
# 1    11
# Name: JobSatisfaction, dtype: int64

# %%
cd["JobSatisfaction"].value_counts()
# Out:
# 4    461
# 3    444
# 1    293
# 2    282
# Name: JobSatisfaction, dtype: int64

# %%
import pandas as pd
cd=pd.read_csv("/content/drive/MyDrive/HR Analysis project/HR_Analytics.csv")
data=cd[(cd["Department"] == "Sales") & (cd["JobRole"]=="Sales Representative")]
final = data["JobSatisfaction"].mean()
print(final)
# Out:
# 2.738095238095238

# %%
import matplotlib.pyplot as plt
number = [1,2,3,4]
plt.pie(cd["JobSatisfaction"].value_counts(),labels= number,startangle=90,autopct='%.2f')
plt.show()

# %%
import pandas as pd
cd=pd.read_csv("/content/drive/MyDrive/HR Analysis project/HR_Analytics.csv")
data=cd[(cd["TrainingTimesLastYear"]>2) & (cd["PerformanceRating"]>2)].count()
print(len(data))
# Out:
# 38

# %%
filtered_df = ab[(ab["TrainingTimesLastYear"] > 2) & (ab["PerformanceRating"] > 2)]
count = filtered_df.shape[0]
print("Number of employees whose training times last year was > 2 and performance rating was > 2:", count)
# Out:
# Number of employees whose training times last year was > 2 and performance rating was > 2: 804

# %%
xaxis=ab["TrainingTimesLastYear"]>1
yaxis=ab["PerformanceRating"]>1
plt.plot(xaxis,yaxis,color="red")
plt.title("Training Times Vs Performance")
plt.xlabel("Training Count")
plt.ylabel("Performance Rating")
plt.show()

# %%
import matplotlib.pyplot as plt

xaxis = ab["TrainingTimesLastYear"]
yaxis = ab["PerformanceRating"]

plt.scatter(xaxis, yaxis, color="red")
plt.title("Training Times Vs Performance")
plt.xlabel("Training Times Last Year")
plt.ylabel("Performance Rating")
plt.show()

# %%
plt.scatter(ab['TrainingTimesLastYear'], ab['PerformanceRating'], color='blue', alpha=0.5)
plt.show()

# %%
cd[(cd["OverTime"]=="Yes") & (cd["JobSatisfaction"]>3)].count()
# Out:
# EmpID                       142
# Age                         142
# AgeGroup                    142
# Attrition                   142
# BusinessTravel              142
# DailyRate                   142
# Department                  142
# DistanceFromHome            142
# Education                   142
# EducationField              142
# EmployeeCount               142
# EmployeeNumber              142
# EnvironmentSatisfaction     142
# Gender                      142
# HourlyRate                  142
# JobInvolvement              142
# JobLevel                    142
# JobRole                     142
# JobSatisfaction             142
# MaritalStatus               142
# MonthlyIncome               142
# SalarySlab                  142
# MonthlyRate                 142
# NumCompaniesWorked          142
# Over18                      142
# OverTime                    142
# PercentSalaryHike           142
# PerformanceRating           142
# RelationshipSatisfaction    142
# ...

# %%
ab_sorted = ab.sort_values(by="AgeGroup")
value_counts_sorted = ab_sorted["AgeGroup"].value_counts()
print("Sorted Value Counts:")
print(value_counts_sorted)
# Out:
# Sorted Value Counts:
# AgeGroup
# 26-35    611
# 36-45    471
# 46-55    228
# 18-25    123
# 55+       47
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
x=ab["AgeGroup"].unique()
plt.pie(ab["AgeGroup"].value_counts(),startangle=90,autopct='%.2f',labels=x)
plt.title("Age Groups of various Employees")
plt.xlabel("Age Groups")
plt.ylabel("Number of People")
plt.show()

# %%
x=["26-35","36-45","46-55","18-25","55+"]
plt.pie(ab["AgeGroup"].value_counts(),labels=x, startangle=90, autopct='%1.1f%%')
plt.title("Age Groups of various Employees")
plt.xlabel("Age Groups")
plt.ylabel("Number of People")
plt.gca().set_aspect('equal')
plt.tight_layout()
plt.show()

# %%
cd["AgeGroup"].unique()
# Out:
# array(['18-25', '26-35', '36-45', '46-55', '55+'], dtype=object)

# %%
cd["Department"].value_counts()
# Out:
# Research & Development    967
# Sales                     450
# Human Resources            63
# Name: Department, dtype: int64

# %%
import matplotlib.pyplot as plt
x=ab["Department"].unique()
y=ab["Department"].value_counts()
plt.bar(x,y,color="Pink")
for i, count in enumerate(y):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom')
plt.title("Employees in Each Department")
plt.xlabel("Department")
plt.ylabel("Number Of Employees")
plt.show()

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/HR Analysis project/HR.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
ab=pd.read_csv("/content/drive/MyDrive/HR Analysis project/HR_Analytics.csv")
ab
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18    18-25       Yes      Travel_Rarely        230
# 1      RM302   18    18-25        No      Travel_Rarely        812
# 2      RM458   18    18-25       Yes  Travel_Frequently       1306
# 3      RM728   18    18-25        No         Non-Travel        287
# 4      RM829   18    18-25       Yes         Non-Travel        247
# ...      ...  ...      ...       ...                ...        ...
# 1475   RM412   60      55+        No      Travel_Rarely        422
# 1476   RM428   60      55+        No  Travel_Frequently       1499
# 1477   RM537   60      55+        No      Travel_Rarely       1179
# 1478   RM880   60      55+        No      Travel_Rarely        696
# 1479  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# 0     Research & Development                 3          3  Life Sciences  ...
# ...

# %%
ab[ab["YearsAtCompany"]>30].count()
# Out:
# EmpID                       16
# Age                         16
# AgeGroup                    16
# Attrition                   16
# BusinessTravel              16
# DailyRate                   16
# Department                  16
# DistanceFromHome            16
# Education                   16
# EducationField              16
# EmployeeCount               16
# EmployeeNumber              16
# EnvironmentSatisfaction     16
# Gender                      16
# HourlyRate                  16
# JobInvolvement              16
# JobLevel                    16
# JobRole                     16
# JobSatisfaction             16
# MaritalStatus               16
# MonthlyIncome               16
# SalarySlab                  16
# MonthlyRate                 16
# NumCompaniesWorked          16
# Over18                      16
# OverTime                    16
# PercentSalaryHike           16
# PerformanceRating           16
# RelationshipSatisfaction    16
# StandardHours               16
# ...

# %%
data=ab[(ab["TrainingTimesLastYear"]>2) & (ab["PerformanceRating"]>2)].count()
print(data)
# Out:
# EmpID                       804
# Age                         804
# AgeGroup                    804
# Attrition                   804
# BusinessTravel              804
# DailyRate                   804
# Department                  804
# DistanceFromHome            804
# Education                   804
# EducationField              804
# EmployeeCount               804
# EmployeeNumber              804
# EnvironmentSatisfaction     804
# Gender                      804
# HourlyRate                  804
# JobInvolvement              804
# JobLevel                    804
# JobRole                     804
# JobSatisfaction             804
# MaritalStatus               804
# MonthlyIncome               804
# SalarySlab                  804
# MonthlyRate                 804
# NumCompaniesWorked          804
# Over18                      804
# OverTime                    804
# PercentSalaryHike           804
# PerformanceRating           804
# RelationshipSatisfaction    804
# ...

# %%
x=ab["TrainingTimesLastYear"]<3
y=ab["PerformanceRating"]>2
plt.plot(x,y,color='lightgreen')
plt.show()

# %%
ab[ab["YearsAtCompany"]>30].count()
# Out:
# EmpID                       16
# Age                         16
# AgeGroup                    16
# Attrition                   16
# BusinessTravel              16
# DailyRate                   16
# Department                  16
# DistanceFromHome            16
# Education                   16
# EducationField              16
# EmployeeCount               16
# EmployeeNumber              16
# EnvironmentSatisfaction     16
# Gender                      16
# HourlyRate                  16
# JobInvolvement              16
# JobLevel                    16
# JobRole                     16
# JobSatisfaction             16
# MaritalStatus               16
# MonthlyIncome               16
# SalarySlab                  16
# MonthlyRate                 16
# NumCompaniesWorked          16
# Over18                      16
# OverTime                    16
# PercentSalaryHike           16
# PerformanceRating           16
# RelationshipSatisfaction    16
# StandardHours               16
# ...

# %%
years_at_company = ab['YearsAtCompany']
plt.hist(years_at_company, color='skyblue', edgecolor='black')
plt.title('Distribution of Years at Company')
plt.xlabel('Years at Company')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
years_at_company = ab['YearsAtCompany']
plt.hist(years_at_company, color='skyblue', edgecolor='black')
bin_values, bin_edges, _ = plt.hist(years_at_company, edgecolor='black')
bin_centers = bin_edges[:-1] + 1.5
for count, x in zip(bin_values, bin_centers):
    plt.text(x, count, str(int(count)), ha='center', va='bottom')
plt.title('Distribution of Years at Company')
plt.xlabel('Years at Company')
plt.ylabel('Number of Employees')
plt.show()

# %%
import matplotlib.pyplot as plt
years_at_company = ab['YearsAtCompany']
more_than_30_years = years_at_company[years_at_company > 30]
plt.hist(more_than_30_years, color='skyblue', edgecolor='black')
bin_values, bin_edges, _ = plt.hist(more_than_30_years, edgecolor='black')
bin_centers = bin_edges[:-1] + 0.5
for count, x in zip(bin_values, bin_centers):
    plt.text(x, count, str(int(count)), ha='center', va='bottom')
plt.title('Distribution of Years Worked (More Than 30 Years)')
plt.xlabel('Years Worked')
plt.ylabel('Number of Employees')
plt.show()

# %%
employees_more_than_30_years =ab[ab['YearsAtCompany'] > 30]
num_employees_more_than_30_years = len(employees_more_than_30_years)
print("Number of employees working more than 30 years:", num_employees_more_than_30_years)
# Out:
# Number of employees working more than 30 years: 16

# %%
divorced_willing_to_work_overtime = ab[(ab['MaritalStatus'] == 'Divorced') & (ab['OverTime'] == 'Yes')]
num_divorced_willing_to_work_overtime = len(divorced_willing_to_work_overtime)
print("Number of married people willing to work overtime:", num_divorced_willing_to_work_overtime)
# Out:
# Number of married people willing to work overtime: 100

# %%
ab[(ab["OverTime"]=="Yes") & (ab["JobSatisfaction"]<2)].count()
# Out:
# EmpID                       85
# Age                         85
# AgeGroup                    85
# Attrition                   85
# BusinessTravel              85
# DailyRate                   85
# Department                  85
# DistanceFromHome            85
# Education                   85
# EducationField              85
# EmployeeCount               85
# EmployeeNumber              85
# EnvironmentSatisfaction     85
# Gender                      85
# HourlyRate                  85
# JobInvolvement              85
# JobLevel                    85
# JobRole                     85
# JobSatisfaction             85
# MaritalStatus               85
# MonthlyIncome               85
# SalarySlab                  85
# MonthlyRate                 85
# NumCompaniesWorked          85
# Over18                      85
# OverTime                    85
# PercentSalaryHike           85
# PerformanceRating           85
# RelationshipSatisfaction    85
# StandardHours               85
# ...

# %%
years_at_company = ab['YearsAtCompany'].value_counts()
years=ab['YearsAtCompany'].count()
plt.bar(years_at_company,years)
plt.show()

# %%
overtime_df = ab[ab["OverTime"] == 'Yes']
job_satisfaction_counts = overtime_df['JobSatisfaction'].value_counts()

job_satisfaction_counts.plot(kind='bar', color='skyblue')
plt.title('Job Satisfaction Levels Among Employees Working Overtime')
plt.xlabel('Job Satisfaction')
plt.ylabel('Number of Employees')
plt.show()

# %%
import matplotlib.pyplot as plt
overtime_df = ab[ab["OverTime"] == 'Yes']
job_satisfaction_counts = overtime_df['JobSatisfaction'].value_counts()
ax = job_satisfaction_counts.plot(kind='bar', color='skyblue')
for i, count in enumerate(job_satisfaction_counts):
    ax.text(i, count + 0.1, str(count), ha='center', va='bottom')
plt.title('Job Satisfaction Levels Among Employees Working Overtime')
plt.xlabel('Job Satisfaction')
plt.ylabel('Number of Employees')
plt.show()

# %%
overtime_df = ab[ab["OverTime"] == 'Yes']
job_satisfaction_counts = overtime_df['JobSatisfaction'].value_counts()
print(job_satisfaction_counts)
# Out:
# JobSatisfaction
# 4    142
# 3    121
# 1     85
# 2     70
# Name: count, dtype: int64

# %%
ef=pd.read_csv("/content/drive/MyDrive/HR Analysis project/Marketing.csv")
ef
# Out:
#       id      c_date         campaign_name    category  campaign_id  \
# 0      1  2021-02-01        facebook_tier1      social       349043
# 1      2  2021-02-01        facebOOK_tier2      social       348934
# 2      3  2021-02-01            google_hot      search     89459845
# 3      4  2021-02-01           google_wide      search       127823
# 4      5  2021-02-01       youtube_blogger  influencer        10934
# ..   ...         ...                   ...         ...          ...
# 303  304  2021-02-28       instagram_tier2      social       983498
# 304  305  2021-02-28  facebook_retargeting      social      4387490
# 305  306  2021-02-28          facebook_lal      social       544756
# 306  307  2021-02-28     instagram_blogger  influencer       374754
# 307  308  2021-02-28        banner_partner       media        39889
#
#      impressions  mark_spent  clicks  leads  orders  revenue
# 0         148263     7307.37    1210     13       1   4981.0
# ...

# %%
ef["clicks"].min()
# Out:
# 20

# %%
ef["clicks"].max()
# Out:
# 61195

# %%
ef["clicks"].mean()
# Out:
# 9739.996753246753

# %%
ef["leads"].mean()
# Out:
# 212.91883116883116

# %%
ef[(ef["clicks"]>9738)& (ef["leads"]>211)].count()
# Out:
# id               81
# c_date           81
# campaign_name    81
# category         81
# campaign_id      81
# impressions      81
# mark_spent       81
# clicks           81
# leads            81
# orders           81
# revenue          81
# dtype: int64

# %%
ef["orders"].mean()
# Out:
# 26.113636363636363

# %%
ef["revenue"].mean()
# Out:
# 139251.1883116883

# %%
ef["revenue"].max()
# Out:
# 2812520.0

# %%
xaxis=ef["orders"]
yaxis=ef["revenue"]
plt.bar(xaxis,yaxis)
plt.show()

# %%
agg_df = ef.groupby('c_date').sum()

# Plotting bar plot
agg_df.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.xlabel('c_date')
plt.ylabel('Count')
plt.title('Total Orders, Revenue, Clicks, and Leads Over Time')
plt.show()

# %%
campaign_data = ef.groupby('campaign_name').sum()[['orders', 'revenue', 'clicks', 'leads']]
campaign_data.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Campaign Name')
plt.ylabel('Count')
plt.title('Total Orders, Revenue, Clicks, and Leads for Each Campaign')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
education_levels = ab['EducationField']
education_counts = education_levels.value_counts()
ax = education_counts.plot(kind='bar', color='purple')
for i, count in enumerate(education_counts):
    ax.text(i, count + 0.1, str(count), ha='center', va='bottom')
plt.title('Distribution of Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Number of Employees')
plt.show()

# %%
education_levels = ab['EducationField']
education_counts = education_levels.value_counts()
print(education_counts)
# Out:
# EducationField
# Life Sciences       607
# Medical             470
# Marketing           161
# Technical Degree    132
# Other                83
# Human Resources      27
# Name: count, dtype: int64

# %%
ab=pd.read_csv("/content/drive/MyDrive/HR Analysis project/HR_Analytics.csv")
data=ab[(ab["TrainingTimesLastYear"]>1) & (ab["PercentSalaryHike"]>15)].count()
print(len(data))
# Out:
# 38

# %%
filtered_df = ab[(ab["TrainingTimesLastYear"] > 1) & (ab["PercentSalaryHike"] >12)]
count = filtered_df.shape[0]
print("Number of employees whose training times last year > 2 and salary hike is  > 10:", count)
# Out:
# Number of employees whose training times last year > 2 and salary hike is  > 10: 979

# %%
ab["TrainingTimesLastYear"].mean()
# Out:
# 2.797972972972973

# %%
gh=pd.read_csv("/content/drive/MyDrive/HR Analysis project/UpdatedResumeDataSet.csv")
gh
# Out:
#          Category                                             Resume
# 0    Data Science  Skills * Programming Languages: Python (pandas...
# 1    Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2    Data Science  Areas of Interest Deep Learning, Control Syste...
# 3    Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4    Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# ..            ...                                                ...
# 957       Testing  Computer Skills: â¢ Proficient in MS office (...
# 958       Testing  â Willingness to accept the challenges. â ...
# 959       Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 960       Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 961       Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
#
# [962 rows x 2 columns]

# %%
filtered_df = ab[(ab["TrainingTimesLastYear"] > 1) & (ab["PercentSalaryHike"] >12)]
count = filtered_df.shape[0]
print("Number of employees whose training times last year > 2 and salary hike is  > 10:", count)

# %%
ab["TrainingTimesLastYear"]>2
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1475     True
# 1476     True
# 1477    False
# 1478     True
# 1479    False
# Name: TrainingTimesLastYear, Length: 1480, dtype: bool

# %%
ab["MonthlyIncome"].mean()
# Out:
# 6504.985810810811

# %%
ab["TrainingTimesLastYear"].mean()
# Out:
# 2.797972972972973

# %%
ab[(ab["TrainingTimesLastYear"]>2) & (ab["MonthlyIncome"]>6500)].count()
# Out:
# EmpID                       261
# Age                         261
# AgeGroup                    261
# Attrition                   261
# BusinessTravel              261
# DailyRate                   261
# Department                  261
# DistanceFromHome            261
# Education                   261
# EducationField              261
# EmployeeCount               261
# EmployeeNumber              261
# EnvironmentSatisfaction     261
# Gender                      261
# HourlyRate                  261
# JobInvolvement              261
# JobLevel                    261
# JobRole                     261
# JobSatisfaction             261
# MaritalStatus               261
# MonthlyIncome               261
# SalarySlab                  261
# MonthlyRate                 261
# NumCompaniesWorked          261
# Over18                      261
# OverTime                    261
# PercentSalaryHike           261
# PerformanceRating           261
# RelationshipSatisfaction    261
# ...

# %%
filtered_df = ab[(ab["TrainingTimesLastYear"] > 1) & (ab["MonthlyIncome"] >4000)]
count = filtered_df.shape[0]
print("Number of employees whose training times last year > 2 and monthly income is  > 4000:", count)
# Out:
# Number of employees whose training times last year > 2 and monthly income is  > 4000: 850

# %%
ab["MonthlyIncome"].max()
# Out:
# 19999

# %%
filtered_data = ab[(ab['TrainingTimesLastYear'] > 2) & (ab['MonthlyIncome'] > 5000)]

plt.scatter(filtered_data['TrainingTimesLastYear'], filtered_data['MonthlyIncome'])
plt.title('Training Time vs Monthly Income (Training Time > 2 & Monthly Income > 6500)')
plt.xlabel('Training Time')
plt.ylabel('Monthly Income')
plt.show()

# %%
filtered_data = ab[(ab['TrainingTimesLastYear'] > 1) & (ab['PercentSalaryHike'] > 15)]
plt.scatter(filtered_data['TrainingTimesLastYear'], filtered_data['PercentSalaryHike'])
plt.title('Training Times vs Percentage Salary Hike (Training Times > 1 & Percentage Salary Hike > 15)')
plt.xlabel('Training Times')
plt.ylabel('Percentage Salary Hike')
plt.show()

# %%
import matplotlib.pyplot as plt
Satisfaction=ab[""].value_counts()
values = [1,2,3,4]
plt.pie(Satisfaction,labels=values,startangle=90,autopct='%.2f')
plt.title("Job Satisfaction of the overall employees working in the company")
plt.xlabel("Job Satisfaction")
plt.ylabel("Satisfaction Percentage")
plt.show()

# %%
department_name = 'Sales'
department_df = ab[ab['Department'] == department_name]
plt.hist(department_df['JobSatisfaction'], bins=10, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Satisfaction Level')
plt.ylabel('Frequency')
plt.title(f'Distribution of Satisfaction Levels in {department_name}')
plt.tight_layout()
plt.show()

# %%
department_name = 'Human Resources'
department_df = ab[ab['Department'] == department_name]
labels=["4-Excellent","3-Good","2-Satisfactory","1-Below Satisfactory"]
satisfaction_counts = department_df['JobSatisfaction'].value_counts()
plt.pie(satisfaction_counts, labels=satisfaction_counts.index, autopct='%1.1f%%', startangle=140)
plt.title(f'Satisfaction Distribution in {department_name}')
plt.legend(labels)
plt.axis('equal')
plt.show()

# %%
data=ab[ab["Department"]=="Human Resources"]
final=data["JobSatisfaction"].value_counts()
print(final)
# Out:
# JobSatisfaction
# 2    20
# 4    17
# 3    15
# 1    11
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'ab' is your DataFrame and 'Gender' and 'MonthlyIncome' are the relevant columns
male_income = ab[ab['Gender'] == 'Male']['MonthlyIncome']
female_income = ab[ab['Gender'] == 'Female']['MonthlyIncome']

# Calculate Summary Statistics
male_summary = male_income.describe()
female_summary = female_income.describe()

print("Male Income Summary:")
print(male_summary)
print("\nFemale Income Summary:")
print(female_summary)
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.hist(male_income, color='blue', alpha=0.7)
plt.title('Distribution of Monthly Income for Males')
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
plt.hist(female_income, color='pink', alpha=0.7)
plt.title('Distribution of Monthly Income for Females')
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# Male Income Summary:
# count      889.000000
# mean      6385.709786
# std       4704.037930
# min       1009.000000
# 25%       2821.000000
# 50%       4851.000000
# 75%       8161.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64
#
# Female Income Summary:
# count      591.000000
# mean      6684.404399
# std       4692.841980
# min       1129.000000
# 25%       3036.000000
# 50%       5070.000000
# 75%       8737.500000
# max      19973.000000
# Name: MonthlyIncome, dtype: float64

# %%
male_income = ab[ab['Gender'] == 'Male']['MonthlyIncome'].mean()
print(male_income)
female_income = ab[ab['Gender'] == 'Female']['MonthlyIncome'].mean()
print(female_income)
# Out:
# 6385.709786276715
# 6684.404399323181

# %%
import matplotlib.pyplot as plt
male_income = ab[ab['Gender'] == 'Male']['MonthlyIncome'].mean()
female_income = ab[ab['Gender'] == 'Female']['MonthlyIncome'].mean()
plt.bar(['Male', 'Female'], [male_income, female_income], color=['blue', 'pink'])
plt.title('Mean Monthly Income by Gender')
plt.xlabel('Gender')
plt.ylabel('Mean Monthly Income')
for i, income in enumerate([male_income, female_income]):
    plt.text(i, income + 100, str(round(income, 2)), ha='center', va='bottom')
plt.show()

# %%
import pandas as pd
male_data = ab[ab['Gender'] == 'Male']
female_data = ab[ab['Gender'] == 'Female']
male_average_salary_by_department = male_data.groupby('Department')['MonthlyIncome'].mean()
female_average_salary_by_department = female_data.groupby('Department')['MonthlyIncome'].mean()
print("Average Salary by Department for Males:")
print(male_average_salary_by_department)
print("\nAverage Salary by Department for Females:")
print(female_average_salary_by_department)
# Out:
# Average Salary by Department for Males:
# Department
# Human Resources           6371.023256
# Research & Development    6133.967632
# Sales                     6958.698842
# Name: MonthlyIncome, dtype: float64
#
# Average Salary by Department for Females:
# Department
# Human Resources           7264.000000
# Research & Development    6506.510526
# Sales                     6977.638743
# Name: MonthlyIncome, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
male_data = ab[ab['Gender'] == 'Male']
female_data = ab[ab['Gender'] == 'Female']
male_average_salary_by_department = male_data.groupby('Department')['MonthlyIncome'].mean()
female_average_salary_by_department = female_data.groupby('Department')['MonthlyIncome'].mean()
plt.bar(male_average_salary_by_department.index, male_average_salary_by_department.values, label='Male', color='blue', alpha=0.7)
plt.bar(female_average_salary_by_department.index, female_average_salary_by_department.values, label='Female', color='pink', alpha=0.7)
plt.title('Average Salary by Department for Males and Females')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create bar plots for average salary by department for males and females
plt.figure(figsize=(10, 6))

# Bar plot for males
plt.bar(male_average_salary_by_department.index, male_average_salary_by_department.values, color='blue', alpha=0.7, label='Male')

# Bar plot for females
plt.bar(female_average_salary_by_department.index, female_average_salary_by_department.values, color='pink', alpha=0.7, label='Female')

plt.title('Average Salary by Department for Males and Females')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
avg_salary = ab.groupby(['Department', 'Gender'])['MonthlyIncome'].mean().unstack()
ax = avg_salary.plot(kind='bar')
plt.title('Average Salary by Department and Gender')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.legend(title='Gender',alignment="right")
plt.xticks(rotation=45)
plt.tight_layout()
for p in ax.patches:
    ax.annotate(f"${p.get_height():.2f}", (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 12), textcoords='offset points')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
gender_satisfaction = ab.groupby('Gender')['JobSatisfaction'].value_counts()
gender_satisfaction.plot(kind='bar', color=['blue', 'pink'])
plt.title('Average Job Satisfaction by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Job Satisfaction')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
gender_satisfaction = ab.groupby('Gender')['JobSatisfaction'].value_counts()
ax = gender_satisfaction.unstack().plot(kind='bar', color=['blue', 'pink','red','green'])
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.title('Average Job Satisfaction by Gender')
plt.xlabel('Gender')
plt.ylabel('Count Of Employees')
plt.show()

# %%
gender_satisfaction = ab.groupby('Gender')['JobSatisfaction'].value_counts()
print(gender_satisfaction)
# Out:
# Gender  JobSatisfaction
# Female  3                  182
#         4                  171
#         1                  120
#         2                  118
# Male    4                  290
#         3                  262
#         1                  173
#         2                  164
# Name: count, dtype: int64

# %%
maritalstatus_satisfaction = ab.groupby('MaritalStatus')['JobSatisfaction'].value_counts()
print(maritalstatus_satisfaction)
# Out:
# MaritalStatus  JobSatisfaction
# Divorced       4                  102
#                3                   94
#                1                   71
#                2                   61
# Married        3                  213
#                4                  202
#                2                  133
#                1                  131
# Single         4                  157
#                3                  137
#                1                   91
#                2                   88
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
gender_satisfaction = ab.groupby('MaritalStatus')['JobSatisfaction'].value_counts()
gender_satisfaction.plot(kind='bar', color=['blue', 'pink','red','green'])
plt.title('Job Satisfaction by MaritalStatus')
plt.xlabel('Marital Status')
plt.ylabel('Job Satisfaction')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
gender_satisfaction = ab.groupby('MaritalStatus')['JobSatisfaction'].value_counts()
ax = gender_satisfaction.unstack().plot(kind='bar', color=['blue', 'pink', 'red', 'green'])
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.title('Job Satisfaction by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Job Satisfaction')
plt.show()

# %%
age_satisfaction = ab.groupby('AgeGroup')['JobSatisfaction'].value_counts()
print(age_satisfaction)
# Out:
# AgeGroup  JobSatisfaction
# 18-25     3                   41
#           4                   36
#           1                   23
#           2                   23
# 26-35     4                  195
#           3                  181
#           1                  123
#           2                  112
# 36-45     4                  152
#           3                  135
#           1                   94
#           2                   90
# 46-55     3                   75
#           4                   62
#           2                   50
#           1                   41
# 55+       4                   16
#           1                   12
#           3                   12
#           2                    7
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
age_satisfaction = ab.groupby('AgeGroup')['JobSatisfaction'].value_counts()
age_satisfaction.unstack().plot(kind='bar', color=['blue', 'pink','green','red'])
plt.title('Average Job Satisfaction by AgeGroup')
plt.xlabel('AgeGroup')
plt.ylabel('Average Job Satisfaction')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
gender_satisfaction = ab.groupby('Gender')['JobSatisfaction'].mean()
ax = gender_satisfaction.plot(kind='bar', color=['blue', 'pink'])
for i, value in enumerate(gender_satisfaction.values):
    ax.text(i, value + 0.1, str(round(value, 2)), ha='center', va='bottom')
plt.title('Average Job Satisfaction by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Job Satisfaction')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
gender_department_satisfaction = ab.groupby(['Gender', 'Department'])['JobSatisfaction'].mean().unstack()
# Visualize the results using a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(gender_department_satisfaction, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Average Job Satisfaction by Gender and Department')
plt.xlabel('Department')
plt.ylabel('Gender')
plt.show()

# %%
gender_department_satisfaction.plot(kind='bar')
plt.title('Average Job Satisfaction by Gender and Department')
plt.xlabel('Department')
plt.ylabel('Average Job Satisfaction')
plt.legend(title='Gender')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
gender_department_satisfaction = ab.groupby(['Gender', 'Department'])['JobSatisfaction'].mean().unstack()
ax = gender_department_satisfaction.plot(kind='bar', figsize=(10, 6))
for i, gender in enumerate(gender_department_satisfaction.index):
    for j, department in enumerate(gender_department_satisfaction.columns):
        value = gender_department_satisfaction.loc[gender, department]
        ax.text(j, value + 0.05, str(round(value, 2)), ha='center', va='bottom')
plt.title('Average Job Satisfaction by Gender and Department')
plt.xlabel('Department')
plt.ylabel('Average Job Satisfaction')
plt.legend(title='Gender')
plt.show()

# %%
ab[(ab["MaritalStatus"]=="Single")& (ab["OverTime"]=="Yes")].count()
# Out:
# EmpID                       131
# Age                         131
# AgeGroup                    131
# Attrition                   131
# BusinessTravel              131
# DailyRate                   131
# Department                  131
# DistanceFromHome            131
# Education                   131
# EducationField              131
# EmployeeCount               131
# EmployeeNumber              131
# EnvironmentSatisfaction     131
# Gender                      131
# HourlyRate                  131
# JobInvolvement              131
# JobLevel                    131
# JobRole                     131
# JobSatisfaction             131
# MaritalStatus               131
# MonthlyIncome               131
# SalarySlab                  131
# MonthlyRate                 131
# NumCompaniesWorked          131
# Over18                      131
# OverTime                    131
# PercentSalaryHike           131
# PerformanceRating           131
# RelationshipSatisfaction    131
# ...

# %%
ab[(ab["MaritalStatus"]=="Divorced")& (ab["OverTime"]=="Yes")].count()
# Out:
# EmpID                       100
# Age                         100
# AgeGroup                    100
# Attrition                   100
# BusinessTravel              100
# DailyRate                   100
# Department                  100
# DistanceFromHome            100
# Education                   100
# EducationField              100
# EmployeeCount               100
# EmployeeNumber              100
# EnvironmentSatisfaction     100
# Gender                      100
# HourlyRate                  100
# JobInvolvement              100
# JobLevel                    100
# JobRole                     100
# JobSatisfaction             100
# MaritalStatus               100
# MonthlyIncome               100
# SalarySlab                  100
# MonthlyRate                 100
# NumCompaniesWorked          100
# Over18                      100
# OverTime                    100
# PercentSalaryHike           100
# PerformanceRating           100
# RelationshipSatisfaction    100
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and it contains columns 'MaritalStatus' and 'OverTime'

# Group the data by marital status and overtime, and calculate the count
marital_overtime_counts = ab.groupby(['MaritalStatus', 'OverTime']).size().unstack()

# Plot the results using a stacked bar plot
marital_overtime_counts.plot(kind='bar', stacked=True, color=['skyblue', 'pink'], figsize=(10, 6))

# Add title and labels
plt.title('Marital Status vs Overtime')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Overtime')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
marital_overtime_counts = ab.groupby(['MaritalStatus', 'OverTime']).size().unstack()
ax = marital_overtime_counts.plot(kind='bar', color=['skyblue', 'pink'])
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2, height), ha='center', va='bottom')
plt.title('Marital Status vs Overtime')
plt.xlabel('Marital Status')
plt.ylabel('Number of Employees')
value=["Not willing to work Overtime(NO)","Willing to work Overtime(Yes)"]
plt.legend(value)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
agegroup_overtime_counts = ab.groupby(['AgeGroup', 'OverTime']).size().unstack()
ax = agegroup_overtime_counts.plot(kind='bar', color=['skyblue', 'pink'])
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2, height), ha='center', va='bottom')
plt.title('AgeGroup vs Overtime')
plt.xlabel('AgeGroup')
plt.ylabel('Number of Employees')
value=["Not Willing to work overtime(NO)","Willing to work overtime(YES)"]
plt.legend(value)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
department_counts = ab['Department'].value_counts()
department_worklifebalance = ab.groupby('Department')['WorkLifeBalance'].mean()
plt.pie(department_worklifebalance, labels=department_worklifebalance.index, autopct='%1.1f%%', startangle=140)
plt.title('Work-Life Balance by Department')
plt.show()

# %%
department_name = 'Human Resources'
department_df = ab[ab['Department'] == department_name]
labels=["1-Very Bad","2-Bad","3-Good","4-Very Good"]
satisfaction_counts = department_df['WorkLifeBalance'].value_counts()
plt.pie(satisfaction_counts, labels=satisfaction_counts.index, autopct='%1.1f%%', startangle=140)
plt.title(f'Satisfaction Distribution in {department_name}')
plt.legend(labels)
plt.show()

# %%
department_name = 'Human Resources'
department_df = ab[ab['Department'] == department_name]
satisfaction_counts = department_df['WorkLifeBalance'].value_counts()
label=["4-Excellent","3-Good","2-Satisfactory","1-Below Satisfactory"]
plt.pie(satisfaction_counts, labels=satisfaction_counts.index, autopct='%1.1f%%', startangle=140)
plt.title(f'Satisfaction Distribution in {department_name}')
plt.legend(label)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
ab.boxplot(column='MonthlyIncome', by='Gender', grid=False, notch=True, vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue'))
plt.title('Salary Distribution by Gender')
plt.xlabel('Salary')
plt.ylabel('Gender')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
ax = ab.boxplot(column='MonthlyIncome', by='Gender', grid=False, notch=True, vert=False, patch_artist=True, boxprops=dict(facecolor='skyblue'))
for i, gender_group in enumerate(ab.groupby('Gender')['MonthlyIncome']):
    gender, group = gender_group
    avg = group.mean()
    ax.text(avg, i + 1, f'{avg:.2f}', ha='center', va='center', color='red', fontweight='bold')

plt.title('Salary Distribution by Gender')
plt.xlabel('Salary')
plt.ylabel('Gender')
plt.show()

# %%
# Out:
#                    EmpID   Age  AgeGroup  Attrition  DailyRate  Department  \
# BusinessTravel
# Non-Travel           151   151       151        151        151         151
# TravelRarely           8     8         8          8          8           8
# Travel_Frequently    279   279       279        279        279         279
# Travel_Rarely       1042  1042      1042       1042       1042        1042
#
#                    DistanceFromHome  Education  EducationField  EmployeeCount  \
# BusinessTravel
# Non-Travel                      151        151             151            151
# TravelRarely                      8          8               8              8
# Travel_Frequently               279        279             279            279
# Travel_Rarely                  1042       1042            1042           1042
#
#                    ...  RelationshipSatisfaction  StandardHours  \
# BusinessTravel     ...
# Non-Travel         ...                       151            151
# ...

# %%
ab.groupby("Department")["BusinessTravel"].value_counts()
# Out:
# Department              BusinessTravel
# Human Resources         Travel_Rarely         45
#                         Travel_Frequently     11
#                         Non-Travel             6
#                         TravelRarely           1
# Research & Development  Travel_Rarely        680
#                         Travel_Frequently    183
#                         Non-Travel            98
#                         TravelRarely           6
# Sales                   Travel_Rarely        317
#                         Travel_Frequently     85
#                         Non-Travel            47
#                         TravelRarely           1
# Name: count, dtype: int64
